# %% [markdown]
# <a href="https://colab.research.google.com/github/danielagz660-png/Notebook_Civil/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CONTENIDOS
# 1. INTRODUCCION
# 2. OBJETIVOS
# 3. METODOLOGIA
# 4. ANALISIS
# 5. ECUACIONES

# %% [markdown]
# # INTRODUCCION
# JSIEWHWEIHIEUFGEUFHIWEHFIEWHFEUW

# %% [markdown]
# # OBJETIVOS
# IJIDUHEWUHFOIEWJFOEHFEWHFOIEO

# %% [markdown]
# ##OBJETIVOS GENERALES
# JENFIEWHFIEHFEJFOEIHJOEIHVOIEHVI

# %% [markdown]
# ## OBJETIVOS ESPECIFICOS
#   * PRIMER OBJETIVO
#   * SEGUNDO OBJETIVO
#   * TERCER OBJETIVO

# %% [markdown]
# # ECUACIONES
#
# 1. Ecuacion de la energia: $E = m*c^2$
#
# Todas las ecuaciones en formato de latex o markdown se encuentran en el siguiente link.
#
# [apuntes de latex](https://metodos.fam.cie.uva.es/~latex/apuntes/apuntes3.pdf)
